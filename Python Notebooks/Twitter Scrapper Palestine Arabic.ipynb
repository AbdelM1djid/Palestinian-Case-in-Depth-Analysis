# %% [markdown]
# Palestine Media Data

# %%
import pandas as pd 
import snscrape.modules.twitter as sntwitter
import csv

# %%
Query  = "(غزة OR فلسطين) min_faves:10 lang:ar until:2022-08-31 since:2022-01-01 -filter:replies"

# %%
Palestine_A = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(Query).get_items()):
    if i>1000000:
        break
    Palestine_A.append([tweet.id, tweet.date,tweet.place,tweet.source,tweet.user.username,tweet.content,tweet.hashtags,tweet.likeCount,tweet.quoteCount,tweet.replyCount,tweet.retweetCount])
    
# Creating a dataframe from the tweets list above
Palestine_Ar = pd.DataFrame(Palestine_A, columns=['Tweet Id', 'DateTime', 'Place', 'Source','Username','Content','hashtags','Likes Number','Quote Number','Reply Number','Retweets Number'])

# %%
Palestine_Ar.shape
# Out:
# (129374, 11)

# %%
Palestine_Ar
# Out:
#                    Tweet Id                  DateTime Place  \
# 0       1564763776913707013 2022-08-30 23:55:30+00:00  None
# 1       1564763137299079168 2022-08-30 23:52:58+00:00  None
# 2       1564762223435735042 2022-08-30 23:49:20+00:00  None
# 3       1564756480854822912 2022-08-30 23:26:31+00:00  None
# 4       1564756315326627841 2022-08-30 23:25:51+00:00  None
# ...                     ...                       ...   ...
# 129369  1477077480573915137 2022-01-01 00:41:28+00:00  None
# 129370  1477076343296778241 2022-01-01 00:36:57+00:00  None
# 129371  1477075145340690437 2022-01-01 00:32:12+00:00  None
# 129372  1477069104687333378 2022-01-01 00:08:11+00:00  None
# 129373  1477068552838418435 2022-01-01 00:06:00+00:00  None
#
#                                                    Source       Username  \
# 0       <a href="http://twitter.com/download/android" ...    maher_jouda
# 1       <a href="http://twitter.com/download/iphone" r...      petgrieff
# 2       <a href="http://twitter.com/download/android" ...     Hamza19819
# 3       <a href="http://twitter.com/download/android" ...  NourThranduil
# 4       <a href="https://mobile.twitter.com" rel="nofo...    AlnashtHmzt
# ...                                                   ...            ...
# 129369  <a href="http://twitter.com/download/iphone" r...    IbtisamAzem
# 129370  <a href="http://twitter.com/download/android" ...  AhmedBatneeji
# 129371  <a href="http://twitter.com/download/iphone" r...     MaherA7med
# 129372  <a href="http://twitter.com/download/android" ...       Rahmon83
# 129373  <a href="https://about.twitter.com/products/tw...      hureyaksa
#
#                                                   Content  \
# 0       ما يحدث في غزة من تغول على حقوق العمال هو نتيج...
# 1       اللي صار اليوم عندنا وفي فلسطين يورينا شكثر أح...
# 2       فى قانون كربلاء ،،\nفاقد الماء قد روى كونآ كام...
# 3       صورة لمسيرة نسائية في غزة تقودها دكتورة مريم أ...
# 4       تعرف شو يعني بناتك في غزة .. تيجي جمعية صهيوني...
# ...                                                   ...
# 129369  على أمل السنة الجاي أفضل من 2021 \nكل عام وأنت...
# 129370  كتيبة ثم سرايا ثم الجندي ثم شارع الوحدة واليوم...
# 129371  لحظة إيقاد شعلة ذكرى إنطلاقة الثورة الفلسطينية...
# 129372  وترجل رمح فلسطين العالي وشاعرها الكبير\nابن جن...
# 129373  من أجمل ما قاله المفكر الإسلامي إبراهيم السكرا...
#
#                                                  hashtags  Likes Number  \
# 0                                                    None            22
# 1                                                    None            16
# 2                                                    None            75
# 3                                                    None            27
# 4                                                    None            14
# ...                                                   ...           ...
# 129369  [فلسطين, العراق, سورية, اليمن, مصر, تونس, السو...            10
# 129370                                               None            32
# 129371                                               None            58
# 129372                                               None            50
# 129373                                               None            68
#
#         Quote Number  Reply Number  Retweets Number
# 0                  0             2                2
# 1                  0             1                4
# 2                  0             5               10
# 3                  0             0                6
# 4                  0             2                0
# ...              ...           ...              ...
# 129369             0             5                0
# 129370             0             0                0
# 129371             1             3               10
# 129372             0             5                7
# 129373             0             0               18
#
# [129374 rows x 11 columns]

# %%
Palestine_Ar['DateTime'] = Palestine_Ar['DateTime'].dt.tz_localize(None)

# %%
Palestine_Ar
# Out:
#                    Tweet Id            DateTime Place  \
# 0       1564763776913707013 2022-08-30 23:55:30  None
# 1       1564763137299079168 2022-08-30 23:52:58  None
# 2       1564762223435735042 2022-08-30 23:49:20  None
# 3       1564756480854822912 2022-08-30 23:26:31  None
# 4       1564756315326627841 2022-08-30 23:25:51  None
# ...                     ...                 ...   ...
# 129369  1477077480573915137 2022-01-01 00:41:28  None
# 129370  1477076343296778241 2022-01-01 00:36:57  None
# 129371  1477075145340690437 2022-01-01 00:32:12  None
# 129372  1477069104687333378 2022-01-01 00:08:11  None
# 129373  1477068552838418435 2022-01-01 00:06:00  None
#
#                                                    Source       Username  \
# 0       <a href="http://twitter.com/download/android" ...    maher_jouda
# 1       <a href="http://twitter.com/download/iphone" r...      petgrieff
# 2       <a href="http://twitter.com/download/android" ...     Hamza19819
# 3       <a href="http://twitter.com/download/android" ...  NourThranduil
# 4       <a href="https://mobile.twitter.com" rel="nofo...    AlnashtHmzt
# ...                                                   ...            ...
# 129369  <a href="http://twitter.com/download/iphone" r...    IbtisamAzem
# 129370  <a href="http://twitter.com/download/android" ...  AhmedBatneeji
# 129371  <a href="http://twitter.com/download/iphone" r...     MaherA7med
# 129372  <a href="http://twitter.com/download/android" ...       Rahmon83
# 129373  <a href="https://about.twitter.com/products/tw...      hureyaksa
#
#                                                   Content  \
# 0       ما يحدث في غزة من تغول على حقوق العمال هو نتيج...
# 1       اللي صار اليوم عندنا وفي فلسطين يورينا شكثر أح...
# 2       فى قانون كربلاء ،،\nفاقد الماء قد روى كونآ كام...
# 3       صورة لمسيرة نسائية في غزة تقودها دكتورة مريم أ...
# 4       تعرف شو يعني بناتك في غزة .. تيجي جمعية صهيوني...
# ...                                                   ...
# 129369  على أمل السنة الجاي أفضل من 2021 \nكل عام وأنت...
# 129370  كتيبة ثم سرايا ثم الجندي ثم شارع الوحدة واليوم...
# 129371  لحظة إيقاد شعلة ذكرى إنطلاقة الثورة الفلسطينية...
# 129372  وترجل رمح فلسطين العالي وشاعرها الكبير\nابن جن...
# 129373  من أجمل ما قاله المفكر الإسلامي إبراهيم السكرا...
#
#                                                  hashtags  Likes Number  \
# 0                                                    None            22
# 1                                                    None            16
# 2                                                    None            75
# 3                                                    None            27
# 4                                                    None            14
# ...                                                   ...           ...
# 129369  [فلسطين, العراق, سورية, اليمن, مصر, تونس, السو...            10
# 129370                                               None            32
# 129371                                               None            58
# 129372                                               None            50
# 129373                                               None            68
#
#         Quote Number  Reply Number  Retweets Number
# 0                  0             2                2
# 1                  0             1                4
# 2                  0             5               10
# 3                  0             0                6
# 4                  0             2                0
# ...              ...           ...              ...
# 129369             0             5                0
# 129370             0             0                0
# 129371             1             3               10
# 129372             0             5                7
# 129373             0             0               18
#
# [129374 rows x 11 columns]

# %%
Palestine_Ar.to_excel("E:\\Work\\Data Analysis Projects\\Palestinian Project\\Twitter Scraped Data\\Palestine_Ar Data.xlsx",index=False)
